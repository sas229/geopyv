# %%
import logging 
import numpy as np
from geopyv.image import Image
from geopyv.templates import Circle, Square
from geopyv.subset import Subset
from geopyv.mesh import Mesh
from geopyv import log

# %%
ref = Image("./tests/ref.jpg")
tar = Image("./tests/tar.jpg")

# %%
subset = Subset(f_img=ref, g_img=tar, f_coord=np.asarray([300,300]), template=Square(25))

# %%
subset.solve()

# %%
subset.convergence()

# %%
subset.inspect()

# %%
subset = Subset()
# Out:
#   2023-01-18 14:06:06,833 - WARNING - geopyv.subset.Subset - _load_f_img - No reference image supplied. Please select the reference image.
#   2023-01-18 14:06:12,479 - WARNING - geopyv.subset.Subset - _load_g_img - No target image supplied. Please select the target image.
#   2023-01-18 14:06:16,940 - WARNING - geopyv.gui.CoordinateSelector - select - No coordinate supplied. Please select the target coordinate for the subset.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 subset = Subset()
#
# File ~/.local/share/virtualenvs/geopyv-IPG7lzKD/lib/python3.10/site-packages/geopyv/subset/Subset.py:130, in Subset.__init__(self, f_coord, f_img, g_img, template)
#     128 # Initialise subset.
#     129 self._get_initial_guess_size()
# --> 130 output = _init_reference(self.f_coord, self.template.coords, self.f_img.QCQT)
#     131 self.f_coords = output[0]
#     132 self.f = output[1]
#
# ValueError: Warp strayed outside of image boundary.
